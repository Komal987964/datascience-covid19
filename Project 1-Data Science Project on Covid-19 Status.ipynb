# %% [markdown]
# ## This project performs EDA(Exploratory Data Analysis) on the given dataset (Latest Covid-19 India Statewise  Distribution).
#
# This dataset contains latest Covid-19 India state-wise data as on July 25, 2021. This dataset can be used to analyze covid condition in India.
# The dataset is taken from Kaggle datasets:https://www.kaggle.com/anandhuh/latest-covid19-india-statewise-data

# %%
# Import all the tool we need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# We want our plots to appear in notebook
# %matplotlib inline

# %%
# Get the data
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Desktop\\sample_project_1'

# %%
# Import the data
df = pd.read_csv("C:\\Users\\admin\\Desktop\\sample_project_1\\Latest Covid-19 India Status.csv")
df
# Out:
#                                    State/UTs  Total Cases   Active  \
# 0                        Andaman and Nicobar         7525       14
# 1                             Andhra Pradesh      1952513    22358
# 2                          Arunachal Pradesh        45703     4465
# 3                                      Assam       557437    15726
# 4                                      Bihar     72439075      530
# 5                                 Chandigarh        61922       32
# 6                               Chhattisgarh      1001037     2789
# 7   Dadra and Nagar Haveli and Daman and Diu        10637       48
# 8                                      Delhi      1435844      587
# 9                                        Goa       170416     1238
# 10                                   Gujarat       824683      342
# 11                                   Haryana       769717      740
# 12                          Himachal Pradesh       205017      931
# ...

# %%
df.shape # rows and columns
# Out:
# (36, 8)

# %% [markdown]
# ## Data Exploration (EDA or Exploratory data analysis)
#
# The goal here is to find out  more about the data and become subject matter expert with the dataset by finding patterns in dataset.

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7525      14        7382     129
# 1       Andhra Pradesh      1952513   22358     1916914   13241
# 2    Arunachal Pradesh        45703    4465       41025     213
# 3                Assam       557437   15726      536597    5114
# 4                Bihar     72439075     530      714223    9637
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.19                98.10             1.71
# 1              1.15                98.18             0.68
# 2              9.77                89.76             0.47
# 3              2.82                96.26             0.92
# 4              0.07                98.60             1.33

# %%
df.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 31      Telengana       640659    9625      627254    3780              1.50
# 32        Tripura        76315    3934       71642     739              5.15
# 33  Uttar Pradesh      1708152     932     1684471   22749              0.05
# 34    Uttarakhand       341673     611      333703    7359              0.18
# 35    West Bengal      1522833   11891     1492878   18064              0.78
#
#     Discharge Ratio (%)  Death Ratio (%)
# 31                97.91             0.59
# 32                93.88             0.97
# 33                98.61             1.33
# 34                97.67             2.15
# 35                98.03             1.19

# %%
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
# Are there any missing values
df.isna().sum()
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %%
df.describe()
# Out:
#         Total Cases        Active    Discharged         Deaths  \
# count  3.600000e+01  3.600000e+01  3.600000e+01      36.000000
# mean   2.863516e+06  4.599578e+04  8.484205e+05   11681.972222
# std    1.199312e+07  2.303794e+05  1.213779e+06   22587.031797
# min    7.525000e+03  1.400000e+01  7.382000e+03       4.000000
# 25%    6.159075e+04  4.830000e+02  5.952950e+04     791.500000
# 50%    4.521775e+05  1.275000e+03  4.390575e+05    5119.000000
# 75%    1.109739e+06  9.781500e+03  9.543658e+05   13308.500000
# max    7.243908e+07  1.386262e+06  6.029817e+06  131429.000000
#
#        Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# count         36.000000            36.000000        36.000000
# mean           2.665833            96.074722         1.260000
# std            4.985038             4.877221         0.565241
# min            0.020000            74.610000         0.040000
# 25%            0.122500            96.327500         0.935000
# ...

# %%
df.dtypes
# Out:
# State/UTs               object
# Total Cases              int64
# Active                   int64
# Discharged               int64
# Deaths                   int64
# Active Ratio (%)       float64
# Discharge Ratio (%)    float64
# Death Ratio (%)        float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
df.nunique()
# Out:
# State/UTs              36
# Total Cases            36
# Active                 36
# Discharged             36
# Deaths                 36
# Active Ratio (%)       33
# Discharge Ratio (%)    32
# Death Ratio (%)        31
# dtype: int64

# %%
len(df)
# Out:
# 36

# %%
df.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(15,10));

# %%
df.plot(x="Total Cases",y="Discharged",kind="bar",figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Total Cases'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
df["Active"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')

# %%
df["Deaths"].plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(x="Total Cases",y="Deaths",kind="scatter",figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='Deaths'>

# %%
df["Total Cases"].mean()
# Out:
# 2863516.277777778

# %%
np.std(df)
# Out:
# Total Cases            1.182538e+07
# Active                 2.271571e+05
# Discharged             1.196802e+06
# Deaths                 2.227111e+04
# Active Ratio (%)       4.915314e+00
# Discharge Ratio (%)    4.809005e+00
# Death Ratio (%)        5.573349e-01
# dtype: float64

# %%
np.var(df)
# Out:
# Total Cases            1.398396e+14
# Active                 5.160036e+10
# Discharged             1.432335e+12
# Deaths                 4.960025e+08
# Active Ratio (%)       2.416031e+01
# Discharge Ratio (%)    2.312652e+01
# Death Ratio (%)        3.106222e-01
# dtype: float64

# %%
df.plot(x="Active",y="Discharged",kind="bar")
# Out:
# <AxesSubplot:xlabel='Active'>

# %%
df.plot(x="Total Cases", y="State/UTs", kind="scatter",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='State/UTs'>

# %%
plt.style.use('ggplot')

# %%
df["Total Cases"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("dark_background")

# %%
df["Discharged"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('seaborn')

# %%
df.plot(x="Total Cases", y="Active", kind="barh",figsize=(10,6))
# Out:
# <AxesSubplot:ylabel='Total Cases'>

# %%
df.plot.hist(figsize=(10,30), subplots=True);

# %%
import seaborn as sns

# %%
sns.relplot(data=df,x="Total Cases", y="Deaths",hue="State/UTs",height=5,aspect=2)

# %%
sns.displot(df["Total Cases"], kind="hist",height=5,aspect=3)

# %%
sns.relplot(data=df,x="Total Cases", y="Active",hue="State/UTs",height=5,aspect=2)

# %%
sns.relplot(data=df,x="Total Cases", y="Discharged",hue="State/UTs",height=5,aspect=2)

# %%
sns.displot(df["Active"], kind="hist",height=5,aspect=3)

# %%
df.corr()
# Out:
#                      Total Cases    Active  Discharged    Deaths  \
# Total Cases             1.000000  0.006699    0.085800  0.080352
# Active                  0.006699  1.000000    0.378549  0.099266
# Discharged              0.085800  0.378549    1.000000  0.914909
# Deaths                  0.080352  0.099266    0.914909  1.000000
# Active Ratio (%)       -0.109418  0.056235   -0.200224 -0.169711
# Discharge Ratio (%)     0.108136 -0.031479    0.192844  0.139060
# Death Ratio (%)         0.031831 -0.224457    0.102526  0.297156
#
#                      Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# Total Cases                 -0.109418             0.108136         0.031831
# Active                       0.056235            -0.031479        -0.224457
# Discharged                  -0.200224             0.192844         0.102526
# Deaths                      -0.169711             0.139060         0.297156
# ...

# %%
corr_matrix = df.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt=".2f",
                cmap="PuBuGn")

# %%
df.to_csv("exported-df.csv")

# %% [markdown]
# ## The project is wrapped up by complete Data analysis on the given datasets.
